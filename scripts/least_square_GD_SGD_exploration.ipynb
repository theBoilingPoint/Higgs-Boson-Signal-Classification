# %%
# Useful starting lines
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load the training data into feature matrix, class labels, and event ids:

# %%
from proj1_helpers import *
DATA_TRAIN_PATH = '../data/train.csv' # TODO: download train data and supply path here 
Y, tX, ids = load_csv_data(DATA_TRAIN_PATH)

# %% [markdown]
# ## Do your thing crazy machine learning thing here :) ...

# %% [markdown]
# ## Preprocess

# %%
from preprocess import one_hot_encode, build_poly

MEAN = None
STD = None
VAL_TO_REPLACE_NEG_999 = None

def preprocess(y, tx, degree=1, strategy='most_freq', log=False, train=True, one_hot_enc=False):
    global MEAN, STD, VAL_TO_REPLACE_NEG_999

    tx = np.copy(tx)

    #for logistic regression, we assum y to be in {0, 1}
    if log:
        y[y < 0] = 0

    if train:
        # Initiate an empty array that will store value to replace -999 of each column
        VAL_TO_REPLACE_NEG_999 = np.zeros(shape=(tx.shape[1],))

    if one_hot_enc:
        col = 22
        one_hot = one_hot_encode(tx[:, col])
        tx = np.c_[tx[:, :col], tx[:, col+1:]]

    # in x there are unknown values marked as -999
    for col in range(tx.shape[1]):
        feature = tx[:,col]
        if train:
            if strategy == 'min':
                min_val = np.min(feature[feature != -999])
                min_val -= 0.001
                feature[feature == -999] = min_val
                VAL_TO_REPLACE_NEG_999[col] = min_val
            elif strategy == 'most_freq':
                values, counts = np.unique(feature[feature != -999], return_counts=True)
                most_freq = values[np.argmax(counts)]
                feature[feature == -999] = most_freq
                VAL_TO_REPLACE_NEG_999[col] = most_freq
            elif strategy == 'mean':
                mean_val = np.mean(feature[feature != -999])
                feature[feature == -999] = mean_val
                VAL_TO_REPLACE_NEG_999[col] = mean_val
        else:
            feature[feature == -999] = VAL_TO_REPLACE_NEG_999[col]
        tx[:,col] = feature

    # in addition, we will add further feature to x
    tx = build_poly(tx, degree)

    # now let's normalize the value in x to mean of 0 and variance of 1
    if train:
        MEAN = np.mean(tx, axis=0)
        STD = np.std(tx, axis=0)
    tx -= MEAN
    tx /= STD

    # let's make a model with shift scalar
    num_samples = len(y)
    tx = np.c_[np.ones(num_samples), tx]

    # concatenate the one hot encoded columns
    if one_hot_enc:
        tx = np.c_[tx, one_hot]

    return y, tx

# %% [markdown]
# ## Training

# %%
from implementations import logistic_regression, compute_loss_logistic_regression, compute_mse, least_squares
from cross_validation import build_k_indices, cross_validation, compute_acc

# %%
seed = 1

np.random.seed(seed)

# %% [markdown]
# ### Gradient Descent

# %%
from implementations import least_squares_GD

# %%
k_fold = 5
max_iters_range = [20]
gammas = [0.001, 0.01, 0.1]

loss_trs = []
loss_tes = []
acc_trs = []
acc_tes = []
ws = []
hyperparameters = []
one_hot_enc = True

for degree in range(1,5):
    for strategy in ['most_freq', 'min', 'mean']:
        y, tx_train = preprocess(Y, tX, degree, strategy=strategy, one_hot_enc=one_hot_enc)
        
        k_indices = build_k_indices(y, k_fold, seed)
        for gamma in gammas:
            for max_iters in max_iters_range:
                acc_tr_mean = acc_te_mean = rmse_tr_mean = rmse_te_mean = 0
                initial_w = np.zeros(tx_train.shape[1])
                initial_w = initial_w.astype(np.float128)
                n = 0
                regression = lambda y, x: least_squares_GD(y, x, initial_w, max_iters, gamma)
                for k in range(k_fold):
                    acc_tr, acc_te, loss_tr, loss_te, weight = cross_validation(y, tx_train, k_indices, k, regression, compute_mse, log=False)
                    ws.append(weight)
                    rmse_tr_mean += loss_tr
                    rmse_te_mean += loss_te
                    acc_tr_mean += acc_tr
                    acc_te_mean += acc_te
                    n += 1
                loss_trs.append(rmse_tr_mean / n)
                loss_tes.append(rmse_te_mean / n)
                acc_trs.append(acc_tr_mean / n)
                acc_tes.append(acc_te_mean / n)
                print(f'Summary: train loss {rmse_tr_mean / n} train acc {acc_tr_mean / n}, test loss {rmse_te_mean / n} test acc {acc_te_mean / n}')

                hyperparameters.append({
                    'max_iters': max_iters,
                    'gamma': gamma,
                    'degree': degree,
                    'strategy': strategy,
                    'one_hot_enc': one_hot_enc
                })
                print('hyperparameters', hyperparameters[-1])
# Out:
# Summary: train loss 0.4681205594929926 train acc 0.681248, test loss 0.46762915179648373 test acc 0.681164
# hyperparameters {'max_iters': 20, 'gamma': 0.001, 'degree': 1, 'strategy': 'most_freq', 'one_hot_enc': True}
# Summary: train loss 0.38693389989744675 train acc 0.71259, test loss 0.3861599581159285 test acc 0.712512
# hyperparameters {'max_iters': 20, 'gamma': 0.01, 'degree': 1, 'strategy': 'most_freq', 'one_hot_enc': True}
# Summary: train loss 0.34453241658526645 train acc 0.737896, test loss 0.3443027960446142 test acc 0.738348
# hyperparameters {'max_iters': 20, 'gamma': 0.1, 'degree': 1, 'strategy': 'most_freq', 'one_hot_enc': True}
# Summary: train loss 0.4680605248108254 train acc 0.667247, test loss 0.46758020506090703 test acc 0.667064
# hyperparameters {'max_iters': 20, 'gamma': 0.001, 'degree': 1, 'strategy': 'min', 'one_hot_enc': True}
# Summary: train loss 0.38723657788448973 train acc 0.7112260000000001, test loss 0.38642376483607105 test acc 0.711192
# hyperparameters {'max_iters': 20, 'gamma': 0.01, 'degree': 1, 'strategy': 'min', 'one_hot_enc': True}
# Summary: train loss 0.3441659343061159 train acc 0.73899, test loss 0.3439341449454367 test acc 0.739336
# hyperparameters {'max_iters': 20, 'gamma': 0.1, 'degree': 1, 'strategy': 'min', 'one_hot_enc': True}
# Summary: train loss 0.47013942755855004 train acc 0.7086749999999999, test loss 0.469658915604045 test acc 0.708572
# hyperparameters {'max_iters': 20, 'gamma': 0.001, 'degree': 1, 'strategy': 'mean', 'one_hot_enc': True}
# Summary: train loss 0.38556377220992827 train acc 0.720072, test loss 0.384706756858879 test acc 0.720124
# hyperparameters {'max_iters': 20, 'gamma': 0.01, 'degree': 1, 'strategy': 'mean', 'one_hot_enc': True}
# Summary: train loss 0.34432052074373354 train acc 0.737976, test loss 0.3441209046690683 test acc 0.738204
# hyperparameters {'max_iters': 20, 'gamma': 0.1, 'degree': 1, 'strategy': 'mean', 'one_hot_enc': True}
# Summary: train loss 0.45830569165929486 train acc 0.6919190000000001, test loss 0.4577040608293298 test acc 0.692128
# hyperparameters {'max_iters': 20, 'gamma': 0.001, 'degree': 2, 'strategy': 'most_freq', 'one_hot_enc': True}
# Summary: train loss 0.37281339741495534 train acc 0.732908, test loss 0.37204994420358567 test acc 0.733276
# hyperparameters {'max_iters': 20, 'gamma': 0.01, 'degree': 2, 'strategy': 'most_freq', 'one_hot_enc': True}
# Summary: train loss 0.32757550757854953 train acc 0.7588739999999999, test loss 0.32753449688619635 test acc 0.758912
# hyperparameters {'max_iters': 20, 'gamma': 0.1, 'degree': 2, 'strategy': 'most_freq', 'one_hot_enc': True}
# Summary: train loss 0.46022833181956874 train acc 0.6671940000000001, test loss 0.4596635903515207 test acc 0.6671199999999999
# hyperparameters {'max_iters': 20, 'gamma': 0.001, 'degree': 2, 'strategy': 'min', 'one_hot_enc': True}
# Summary: train loss 0.3748330336477355 train acc 0.7290270000000001, test loss 0.3740068927267951 test acc 0.7289479999999999
# hyperparameters {'max_iters': 20, 'gamma': 0.01, 'degree': 2, 'strategy': 'min', 'one_hot_enc': True}
# Summary: train loss 0.3289851718242552 train acc 0.757856, test loss 0.32895516348970694 test acc 0.757964
# hyperparameters {'max_iters': 20, 'gamma': 0.1, 'degree': 2, 'strategy': 'min', 'one_hot_enc': True}
# Summary: train loss 0.45900048329907683 train acc 0.711207, test loss 0.4583801146219191 test acc 0.7112120000000001
# hyperparameters {'max_iters': 20, 'gamma': 0.001, 'degree': 2, 'strategy': 'mean', 'one_hot_enc': True}
# Summary: train loss 0.3721577571007518 train acc 0.734758, test loss 0.3714193649037166 test acc 0.7343399999999999
# hyperparameters {'max_iters': 20, 'gamma': 0.01, 'degree': 2, 'strategy': 'mean', 'one_hot_enc': True}
# Summary: train loss 0.3278784383089454 train acc 0.758193, test loss 0.3278347746023203 test acc 0.758572
# hyperparameters {'max_iters': 20, 'gamma': 0.1, 'degree': 2, 'strategy': 'mean', 'one_hot_enc': True}
# Summary: train loss 0.4544593320666243 train acc 0.693891, test loss 0.4538502021905841 test acc 0.6939919999999999
# hyperparameters {'max_iters': 20, 'gamma': 0.001, 'degree': 3, 'strategy': 'most_freq', 'one_hot_enc': True}
# Summary: train loss 0.370265756643351 train acc 0.731553, test loss 0.3694992918660468 test acc 0.731336
# hyperparameters {'max_iters': 20, 'gamma': 0.01, 'degree': 3, 'strategy': 'most_freq', 'one_hot_enc': True}
# Summary: train loss 0.3261923612036783 train acc 0.7603509999999999, test loss 0.3266285829506331 test acc 0.7605039999999998
# hyperparameters {'max_iters': 20, 'gamma': 0.1, 'degree': 3, 'strategy': 'most_freq', 'one_hot_enc': True}
# Summary: train loss 0.45603262155283925 train acc 0.665913, test loss 0.45546010447470114 test acc 0.666244
# hyperparameters {'max_iters': 20, 'gamma': 0.001, 'degree': 3, 'strategy': 'min', 'one_hot_enc': True}
# Summary: train loss 0.37144388990194227 train acc 0.728847, test loss 0.3706139241811828 test acc 0.7291160000000001
# hyperparameters {'max_iters': 20, 'gamma': 0.01, 'degree': 3, 'strategy': 'min', 'one_hot_enc': True}
# Summary: train loss 285473759.7014557 train acc 0.379632, test loss 368784176.1364207 test acc 0.379452
# hyperparameters {'max_iters': 20, 'gamma': 0.1, 'degree': 3, 'strategy': 'min', 'one_hot_enc': True}
# Summary: train loss 0.4548965493179662 train acc 0.710534, test loss 0.4542598066459484 test acc 0.7103800000000001
# hyperparameters {'max_iters': 20, 'gamma': 0.001, 'degree': 3, 'strategy': 'mean', 'one_hot_enc': True}
# Summary: train loss 0.3697621171560496 train acc 0.732, test loss 0.3690412427124066 test acc 0.7319319999999999
# hyperparameters {'max_iters': 20, 'gamma': 0.01, 'degree': 3, 'strategy': 'mean', 'one_hot_enc': True}
# Summary: train loss 0.3265828510118317 train acc 0.7595780000000001, test loss 0.32704748389531646 test acc 0.760092
# hyperparameters {'max_iters': 20, 'gamma': 0.1, 'degree': 3, 'strategy': 'mean', 'one_hot_enc': True}
# Summary: train loss 0.45124071207800365 train acc 0.696332, test loss 0.45062447330355854 test acc 0.696012
# hyperparameters {'max_iters': 20, 'gamma': 0.001, 'degree': 4, 'strategy': 'most_freq', 'one_hot_enc': True}
# Summary: train loss 0.36827581636454776 train acc 0.732148, test loss 0.3675093299370142 test acc 0.732236
# hyperparameters {'max_iters': 20, 'gamma': 0.01, 'degree': 4, 'strategy': 'most_freq', 'one_hot_enc': True}
# Summary: train loss 0.3249882959809067 train acc 0.761955, test loss 0.3254688390351546 test acc 0.7622440000000001
# hyperparameters {'max_iters': 20, 'gamma': 0.1, 'degree': 4, 'strategy': 'most_freq', 'one_hot_enc': True}
# Summary: train loss 0.45333047090564793 train acc 0.664744, test loss 0.4527513119297458 test acc 0.665152
# hyperparameters {'max_iters': 20, 'gamma': 0.001, 'degree': 4, 'strategy': 'min', 'one_hot_enc': True}
# Summary: train loss 0.36957463129796153 train acc 0.7310860000000001, test loss 0.3687465039463712 test acc 0.731236
# hyperparameters {'max_iters': 20, 'gamma': 0.01, 'degree': 4, 'strategy': 'min', 'one_hot_enc': True}
# Summary: train loss 2.948153277363998e+35 train acc 0.37307199999999996, test loss 7.157926445134003e+35 test acc 0.37308
# hyperparameters {'max_iters': 20, 'gamma': 0.1, 'degree': 4, 'strategy': 'min', 'one_hot_enc': True}
# Summary: train loss 0.451441753006713 train acc 0.7093689999999999, test loss 0.4507977655015613 test acc 0.7097559999999999
# hyperparameters {'max_iters': 20, 'gamma': 0.001, 'degree': 4, 'strategy': 'mean', 'one_hot_enc': True}
# Summary: train loss 0.36788198549720175 train acc 0.732691, test loss 0.3671543013578779 test acc 0.732508
# hyperparameters {'max_iters': 20, 'gamma': 0.01, 'degree': 4, 'strategy': 'mean', 'one_hot_enc': True}
# Summary: train loss 0.3253024759821984 train acc 0.7610250000000001, test loss 0.32584669998920357 test acc 0.7611000000000001
# hyperparameters {'max_iters': 20, 'gamma': 0.1, 'degree': 4, 'strategy': 'mean', 'one_hot_enc': True}

# %%
hype = pd.DataFrame(hyperparameters)
hype['accur_test'] = acc_tes
hype['loss_train'] =loss_trs

# %%
hype
# Out:
#     max_iters  gamma  degree   strategy  one_hot_enc  accur_test    loss_train
# 0          20  0.001       1  most_freq         True    0.681164  4.681206e-01
# 1          20  0.010       1  most_freq         True    0.712512  3.869339e-01
# 2          20  0.100       1  most_freq         True    0.738348  3.445324e-01
# 3          20  0.001       1        min         True    0.667064  4.680605e-01
# 4          20  0.010       1        min         True    0.711192  3.872366e-01
# 5          20  0.100       1        min         True    0.739336  3.441659e-01
# 6          20  0.001       1       mean         True    0.708572  4.701394e-01
# 7          20  0.010       1       mean         True    0.720124  3.855638e-01
# 8          20  0.100       1       mean         True    0.738204  3.443205e-01
# 9          20  0.001       2  most_freq         True    0.692128  4.583057e-01
# 10         20  0.010       2  most_freq         True    0.733276  3.728134e-01
# 11         20  0.100       2  most_freq         True    0.758912  3.275755e-01
# 12         20  0.001       2        min         True    0.667120  4.602283e-01
# 13         20  0.010       2        min         True    0.728948  3.748330e-01
# 14         20  0.100       2        min         True    0.757964  3.289852e-01
# 15         20  0.001       2       mean         True    0.711212  4.590005e-01
# 16         20  0.010       2       mean         True    0.734340  3.721578e-01
# 17         20  0.100       2       mean         True    0.758572  3.278784e-01
# 18         20  0.001       3  most_freq         True    0.693992  4.544593e-01
# 19         20  0.010       3  most_freq         True    0.731336  3.702658e-01
# 20         20  0.100       3  most_freq         True    0.760504  3.261924e-01
# 21         20  0.001       3        min         True    0.666244  4.560326e-01
# 22         20  0.010       3        min         True    0.729116  3.714439e-01
# 23         20  0.100       3        min         True    0.379452  2.854738e+08
# 24         20  0.001       3       mean         True    0.710380  4.548965e-01
# 25         20  0.010       3       mean         True    0.731932  3.697621e-01
# 26         20  0.100       3       mean         True    0.760092  3.265829e-01
# 27         20  0.001       4  most_freq         True    0.696012  4.512407e-01
# 28         20  0.010       4  most_freq         True    0.732236  3.682758e-01
# 29         20  0.100       4  most_freq         True    0.762244  3.249883e-01
# 30         20  0.001       4        min         True    0.665152  4.533305e-01
# 31         20  0.010       4        min         True    0.731236  3.695746e-01
# 32         20  0.100       4        min         True    0.373080  2.948153e+35
# 33         20  0.001       4       mean         True    0.709756  4.514418e-01
# 34         20  0.010       4       mean         True    0.732508  3.678820e-01
# 35         20  0.100       4       mean         True    0.761100  3.253025e-01

# %% [markdown]
# ### Stochastic Gradient Descent

# %%
from implementations import least_squares_SGD

# %%
k_fold = 5
max_iters_range = [20]
gammas = [0.001, 0.01, 0.1]

loss_trs = []
loss_tes = []
acc_trs = []
acc_tes = []
ws = []
hyperparameters_sgd = []
one_hot_enc = True

for degree in range(1,5):
    for strategy in ['most_freq', 'min', 'mean']:
        y, tx_train = preprocess(Y, tX, degree, strategy=strategy, one_hot_enc=one_hot_enc)
        
        k_indices = build_k_indices(y, k_fold, seed)
        for gamma in gammas:
            for max_iters in max_iters_range:
                acc_tr_mean = acc_te_mean = rmse_tr_mean = rmse_te_mean = 0
                initial_w = np.zeros(tx_train.shape[1])
                initial_w = initial_w.astype(np.float128)
                n = 0
                regression = lambda y, x: least_squares_SGD(y, x, initial_w, max_iters, gamma)
                for k in range(k_fold):
                    acc_tr, acc_te, loss_tr, loss_te, weight = cross_validation(y, tx_train, k_indices, k, regression, compute_mse, log=False)
                    ws.append(weight)
                    rmse_tr_mean += loss_tr
                    rmse_te_mean += loss_te
                    acc_tr_mean += acc_tr
                    acc_te_mean += acc_te
                    n += 1
                loss_trs.append(rmse_tr_mean / n)
                loss_tes.append(rmse_te_mean / n)
                acc_trs.append(acc_tr_mean / n)
                acc_tes.append(acc_te_mean / n)
                print(f'Summary: train loss {rmse_tr_mean / n} train acc {acc_tr_mean / n}, test loss {rmse_te_mean / n} test acc {acc_te_mean / n}')

                hyperparameters_sgd.append({
                    'max_iters': max_iters,
                    'gamma': gamma,
                    'degree': degree,
                    'strategy': strategy,
                    'one_hot_enc': one_hot_enc
                })
                print('hyperparameters', hyperparameters_sgd[-1])
# Out:
# Summary: train loss 0.47727750013242964 train acc 0.654551, test loss 0.4760869012414026 test acc 0.6539400000000001
# hyperparameters {'max_iters': 20, 'gamma': 0.001, 'degree': 1, 'strategy': 'most_freq', 'one_hot_enc': True}
# Summary: train loss 0.42593925996573967 train acc 0.6842469999999999, test loss 0.4251306308589764 test acc 0.685048
# hyperparameters {'max_iters': 20, 'gamma': 0.01, 'degree': 1, 'strategy': 'most_freq', 'one_hot_enc': True}
# Summary: train loss 578796.8672432419 train acc 0.48264200000000007, test loss 715174.763181222 test acc 0.4812600000000001
# hyperparameters {'max_iters': 20, 'gamma': 0.1, 'degree': 1, 'strategy': 'most_freq', 'one_hot_enc': True}
# Summary: train loss 0.4775133195117001 train acc 0.6447680000000001, test loss 0.4763342565317616 test acc 0.6445000000000001
# hyperparameters {'max_iters': 20, 'gamma': 0.001, 'degree': 1, 'strategy': 'min', 'one_hot_enc': True}
# Summary: train loss 0.4217461206781293 train acc 0.6820700000000001, test loss 0.41946928341079953 test acc 0.6825519999999999
# hyperparameters {'max_iters': 20, 'gamma': 0.01, 'degree': 1, 'strategy': 'min', 'one_hot_enc': True}
# Summary: train loss 79892.155256605 train acc 0.502704, test loss 299411.20842152875 test acc 0.501252
# hyperparameters {'max_iters': 20, 'gamma': 0.1, 'degree': 1, 'strategy': 'min', 'one_hot_enc': True}
# Summary: train loss 0.4748614853324108 train acc 0.672599, test loss 0.47399056332725126 test acc 0.6715479999999999
# hyperparameters {'max_iters': 20, 'gamma': 0.001, 'degree': 1, 'strategy': 'mean', 'one_hot_enc': True}
# Summary: train loss 0.4324872082862397 train acc 0.680747, test loss 0.43157427621679695 test acc 0.680992
# hyperparameters {'max_iters': 20, 'gamma': 0.01, 'degree': 1, 'strategy': 'mean', 'one_hot_enc': True}
# Summary: train loss 17432815.522729628 train acc 0.516284, test loss 16946194.874728106 test acc 0.516148
# hyperparameters {'max_iters': 20, 'gamma': 0.1, 'degree': 1, 'strategy': 'mean', 'one_hot_enc': True}
# Summary: train loss 0.4717741862007717 train acc 0.661249, test loss 0.47008073721216825 test acc 0.660708
# hyperparameters {'max_iters': 20, 'gamma': 0.001, 'degree': 2, 'strategy': 'most_freq', 'one_hot_enc': True}
# Summary: train loss 0.47748024104666004 train acc 0.685651, test loss 0.4607656493165076 test acc 0.6856320000000001
# hyperparameters {'max_iters': 20, 'gamma': 0.01, 'degree': 2, 'strategy': 'most_freq', 'one_hot_enc': True}
# Summary: train loss 3.0796670890966268e+16 train acc 0.48715, test loss 4.804221201435926e+16 test acc 0.486168
# hyperparameters {'max_iters': 20, 'gamma': 0.1, 'degree': 2, 'strategy': 'most_freq', 'one_hot_enc': True}
# Summary: train loss 0.4741089351578947 train acc 0.64278, test loss 0.47243281221313743 test acc 0.6432840000000001
# hyperparameters {'max_iters': 20, 'gamma': 0.001, 'degree': 2, 'strategy': 'min', 'one_hot_enc': True}
# Summary: train loss 0.5080033297608127 train acc 0.668122, test loss 0.4807241151109569 test acc 0.666876
# hyperparameters {'max_iters': 20, 'gamma': 0.01, 'degree': 2, 'strategy': 'min', 'one_hot_enc': True}
# Summary: train loss 2.0685164550302765e+21 train acc 0.536173, test loss 2.691514276419537e+21 test acc 0.536176
# hyperparameters {'max_iters': 20, 'gamma': 0.1, 'degree': 2, 'strategy': 'min', 'one_hot_enc': True}
# Summary: train loss 0.4692703746343329 train acc 0.677864, test loss 0.46795944105767046 test acc 0.678284
# hyperparameters {'max_iters': 20, 'gamma': 0.001, 'degree': 2, 'strategy': 'mean', 'one_hot_enc': True}
# Summary: train loss 0.5682051271257167 train acc 0.6793130000000001, test loss 0.5281826621381825 test acc 0.6796880000000001
# hyperparameters {'max_iters': 20, 'gamma': 0.01, 'degree': 2, 'strategy': 'mean', 'one_hot_enc': True}
# Summary: train loss 1508882242206.4739 train acc 0.4907909999999999, test loss 2551330752697.603 test acc 0.491048
# hyperparameters {'max_iters': 20, 'gamma': 0.1, 'degree': 2, 'strategy': 'mean', 'one_hot_enc': True}
# Summary: train loss 0.4720634126904593 train acc 0.6496660000000001, test loss 0.4703344716456646 test acc 0.6493840000000001
# hyperparameters {'max_iters': 20, 'gamma': 0.001, 'degree': 3, 'strategy': 'most_freq', 'one_hot_enc': True}
# Summary: train loss 0.5618284178809917 train acc 0.6699759999999999, test loss 0.5320333817718179 test acc 0.6693680000000001
# hyperparameters {'max_iters': 20, 'gamma': 0.01, 'degree': 3, 'strategy': 'most_freq', 'one_hot_enc': True}
# Summary: train loss 3.036990278282925e+21 train acc 0.5260640000000001, test loss 1.943970545333065e+22 test acc 0.5267760000000001
# hyperparameters {'max_iters': 20, 'gamma': 0.1, 'degree': 3, 'strategy': 'most_freq', 'one_hot_enc': True}
# Summary: train loss 0.4753092591232148 train acc 0.6229229999999999, test loss 0.4735796752164549 test acc 0.6231199999999999
# hyperparameters {'max_iters': 20, 'gamma': 0.001, 'degree': 3, 'strategy': 'min', 'one_hot_enc': True}
# Summary: train loss 0.9270786144841812 train acc 0.643644, test loss 0.8058568306263075 test acc 0.642064
# hyperparameters {'max_iters': 20, 'gamma': 0.01, 'degree': 3, 'strategy': 'min', 'one_hot_enc': True}
# Summary: train loss 2.3067380041992456e+31 train acc 0.50661, test loss 9.350746994740444e+31 test acc 0.505852
# hyperparameters {'max_iters': 20, 'gamma': 0.1, 'degree': 3, 'strategy': 'min', 'one_hot_enc': True}
# Summary: train loss 0.4687164293822182 train acc 0.663173, test loss 0.4673970903423117 test acc 0.663092
# hyperparameters {'max_iters': 20, 'gamma': 0.001, 'degree': 3, 'strategy': 'mean', 'one_hot_enc': True}
# Summary: train loss 0.8135062450337718 train acc 0.667095, test loss 0.7195011591620148 test acc 0.666968
# hyperparameters {'max_iters': 20, 'gamma': 0.01, 'degree': 3, 'strategy': 'mean', 'one_hot_enc': True}
# Summary: train loss 2.564985100474117e+20 train acc 0.460532, test loss 1.2290657417085644e+21 test acc 0.45925200000000005
# hyperparameters {'max_iters': 20, 'gamma': 0.1, 'degree': 3, 'strategy': 'mean', 'one_hot_enc': True}
# Summary: train loss 0.47042358291408837 train acc 0.64606, test loss 0.4686807973031067 test acc 0.645976
# hyperparameters {'max_iters': 20, 'gamma': 0.001, 'degree': 4, 'strategy': 'most_freq', 'one_hot_enc': True}
# Summary: train loss 0.6649369774042634 train acc 0.659102, test loss 0.6215106012201147 test acc 0.65778
# hyperparameters {'max_iters': 20, 'gamma': 0.01, 'degree': 4, 'strategy': 'most_freq', 'one_hot_enc': True}
# Summary: train loss 1.1994554715135099e+22 train acc 0.5174570000000001, test loss 3.2924698143870505e+22 test acc 0.516964
# hyperparameters {'max_iters': 20, 'gamma': 0.1, 'degree': 4, 'strategy': 'most_freq', 'one_hot_enc': True}
# Summary: train loss 0.47414068833188366 train acc 0.6164149999999999, test loss 0.47242895225162607 test acc 0.6169680000000001
# hyperparameters {'max_iters': 20, 'gamma': 0.001, 'degree': 4, 'strategy': 'min', 'one_hot_enc': True}
# Summary: train loss 1.6545161867593257 train acc 0.62277, test loss 1.3920557728391154 test acc 0.6212479999999999
# hyperparameters {'max_iters': 20, 'gamma': 0.01, 'degree': 4, 'strategy': 'min', 'one_hot_enc': True}
# Summary: train loss 1.9081500691145343e+43 train acc 0.4993879999999999, test loss 1.6286970799755159e+43 test acc 0.499788
# hyperparameters {'max_iters': 20, 'gamma': 0.1, 'degree': 4, 'strategy': 'min', 'one_hot_enc': True}
# Summary: train loss 0.4674694071655358 train acc 0.657567, test loss 0.46611359925658075 test acc 0.657848
# hyperparameters {'max_iters': 20, 'gamma': 0.001, 'degree': 4, 'strategy': 'mean', 'one_hot_enc': True}
# Summary: train loss 1.1622545535389461 train acc 0.660215, test loss 0.9919563535988601 test acc 0.6599679999999999
# hyperparameters {'max_iters': 20, 'gamma': 0.01, 'degree': 4, 'strategy': 'mean', 'one_hot_enc': True}
# Summary: train loss 1.1455543681751448e+26 train acc 0.49538100000000007, test loss 7.571047072103692e+26 test acc 0.494116
# hyperparameters {'max_iters': 20, 'gamma': 0.1, 'degree': 4, 'strategy': 'mean', 'one_hot_enc': True}

# %% [markdown]
# ## Generate predictions and save ouput in csv format for submission:

# %%
DATA_TEST_PATH = '../data/test.csv' # TODO: download train data and supply path here 
_, tX_test, ids_test = load_csv_data(DATA_TEST_PATH)
_, tX_test = preprocess(_, tX_test, degree=2, strategy='most_freq', train=False)
# Out:
# (568238, 30) before
# (568238, 29) remove col to be one hot

# %%
tX_test.shape
# Out:
# (568238, 63)

# %%
OUTPUT_PATH = '../data/pred_least_squre_normalized_poly2_properonehot_10fold_mean_weight.csv' # TODO: fill in desired name of output file for submission
y_pred = make_prediction(tX_test, weighted_mean, threshold=0, log=False)
create_csv_submission(ids_test, y_pred, OUTPUT_PATH)
